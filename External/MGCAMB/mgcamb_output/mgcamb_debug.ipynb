# %% [markdown]
# # MGCAMB Debugging notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 3.4. Hu_Sawicki $f(R)$ gravity

# %%
v2 = np.loadtxt('../../../../MGCAMB_Jan_2015/CAMB/fort.1')
v3 = np.loadtxt('./../fort.777')

# %%
v3[0,0]
# Out:
# 0.11218328266424046

# %%
v2[0,0]
# Out:
# 0.11218328266424046

# %%
v2.shape
# Out:
# (55601, 14)

# %%
v3.shape
# Out:
# (55601, 14)

# %%
plt.plot(v2[:,1], v2[:,2], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,2], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('mu')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,3], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,3], linestyle = '--', color = 'C1', linewidth=2)
plt.show()

# %%
plt.plot(v2[:,1], v2[:,4], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,4], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('sigma')
plt.show()

# %%
plt.loglog(v2[:,1], v2[:,5], linestyle = '-', color = 'C0', linewidth=1)
plt.loglog(v3[:,1], v3[:,5], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term1')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,6], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,6], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term2')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,7], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,7], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term3')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,8], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,8], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term4')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,9], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,9], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term5')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,10], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,10], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('term6')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,11], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,11], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('etadot')
plt.show()

# %%
plt.loglog(v2[:,1], v2[:,12], linestyle = '-', color = 'C0', linewidth=1)
plt.loglog(v3[:,1], v3[:,12], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('fmu')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,13], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,13], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('grhonu')
plt.show()

# %%
## MG functions

# %%
v2 = np.loadtxt('../../../../MGCAMB_Jan_2015/CAMB/fort.2')
v3 = np.loadtxt('./../fort.888')

# %%
plt.plot(v2[:,1], v2[:,2], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,2], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('H')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,3], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,3], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('mu')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,4], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,4], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('gamma')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,5], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,5], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('mudot')
plt.show()

# %%
plt.plot(v2[:,1], v2[:,6], linestyle = '-', color = 'C0', linewidth=1)
plt.plot(v3[:,1], v3[:,6], linestyle = '--', color = 'C1', linewidth=2)
plt.xlabel('a')
plt.ylabel('gammadot')
plt.show()
